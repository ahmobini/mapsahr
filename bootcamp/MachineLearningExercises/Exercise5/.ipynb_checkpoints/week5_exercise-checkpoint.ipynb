# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=6 color=#F32500>
#         <div  align=center>
#             تمرین هفته پنجم بوت کمپ یادگیری ماشین-
#             مپصا
#         </div>
#         <br/>
#     </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<div align=center>
# 			<font face="IranNastaliq" size=5>
#                   چون عهده نمی‌شود کسی فردا را
#                 <br><br>
#                  حالی خوش دار این دل پر سودا را
#                 <br><br>
#                 می نوش به ماهتاب ای ماه که ماه
#                 <br><br>
#                 بسیار بتابد و نیابد ما را
#                 <p></p>
# 			</font>
#         </div>
#     </font>
# </div>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال اول:‌
#             </font>
#         <font>
#             مجموعه داده های زیر را در نظر بگیرید
#         </font>
#         <br/>
#     </font>
# </div>

# %%
numbers = np.array([ 4.5 , 7.8 ,  6.5,  0.5,  8. ,  6.5, 19. , 13.5,  2.5, 17. , 19. ,
       19.5, 13. ,  12.21 ,  6.3 ,  0.5,  9.5, 13.5, 16. ,  2.5, 10.5,  8. ,
       10. , 15.5,  7.5,  0. ,  1. , 10.5,  2. , 11. ,  3. , 14. ,  3.5,
       18.5, 13. ,  1. , 14.5, 15. ,  1.52 , 15.5,  1.5,  2.8 ,  3.5,  6.5,
        12.5, 14.5, 11.5,  8. ,  10.2 ,  5.5,  0.5, 23. ,  5. ,  0.5, 17.5,
       17.5, 17.5, 15. ,  4.5, 17. , 18. , 10. ,  8.5, 14. , 18.5, 19.5,
       16.3 ,  8.5,  0. ,  9.5,  6. ,  2. ,  5. ,  9.5,  4. ,  4. ,  1. ,
        8. , 18.5, 18. , 15.5,  4.5,  1.5, 20. ,  0.5, 19. ,  4. ,  9.5,
       12.8  ])

# %% [markdown]
# <div id="bayes" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<p></p>
#         برای این مجموعه داده ها قصد داریم با دو فرمول زیر مقادیر آنها را تغییر دهیم:
# <br>
# ۱. اگر عددی کمتر از هشت و نیم است با فرمول زیر آن عدد تغییر کند:
# <br>
# $$ y = 10 + \frac{x}{10} $$
# <br>
# ۲. اگر عددیبیشتر یا مساوی هشت و نیم است با فرمول زیر آن عدد تغییر کند :
# <br>
# $$ y =  -0.0051x^{2} + 0.8586x + 3.4332 $$
# <br>
# توجه کنید که حتی بعد از تغییر باید بیشینه عدد نهایتا بیشینه عدد موجود در داده فعلی باشد.
#         25 درصد داده های بزرگتر را در آرایه زیر بریزید
# </div>

# %%
num = np.where(numbers < 8.5, numbers, 10 + 0.1 * numbers)
sorted_ = np.sort(num)
upper_twenty_Percent = sorted_[:num.size//4]
upper_twenty_Percent
# Out:
# array([0.  , 0.  , 0.5 , 0.5 , 0.5 , 0.5 , 0.5 , 1.  , 1.  , 1.  , 1.5 ,
#        1.5 , 1.52, 2.  , 2.  , 2.5 , 2.5 , 2.8 , 3.  , 3.5 , 3.5 , 4.  ])

# %% [markdown]
# <div id="bayes" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<p></p>
#  25 درصد داده های کوچکتر آرایه اول را در آرایه زیر بریزید
# </div>

# %%
num = np.where(numbers >= 8.5, numbers, -0.0051 * numbers**2 + 0.8586 * numbers + 3.4332)
sorted_ = np.sort(num)
lower_twenty_Percent = sorted_[:num.size//4]
lower_twenty_Percent
# Out:
# array([3.4332    , 3.4332    , 3.861225  , 3.861225  , 3.861225  ,
#        3.861225  , 3.861225  , 4.2867    , 4.2867    , 4.2867    ,
#        4.709625  , 4.709625  , 4.72648896, 5.13      , 5.13      ,
#        5.547825  , 5.547825  , 5.797296  , 5.9631    , 6.375825  ,
#        6.375825  , 6.786     ])

# %% [markdown]
# <div id="bayes" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#       <p></p>
#         داده های متناظر دو آرایه به دست آمده را از یکدیگر کسر کنید و در یک آرایه سه بعدی که اندازه ابعاد سوم و دوم آن یک میباشد بریزید
# </div>

# %%
# lower_twenty_Percent.size
# upper_twenty_Percent.size
difference = upper_twenty_Percent-lower_twenty_Percent
np.reshape(difference, (22,1,1))
# Out:
# array([[[-3.4332    ]],
#
#        [[-3.4332    ]],
#
#        [[-3.361225  ]],
#
#        [[-3.361225  ]],
#
#        [[-3.361225  ]],
#
#        [[-3.361225  ]],
#
#        [[-3.361225  ]],
#
#        [[-3.2867    ]],
#
#        [[-3.2867    ]],
#
#        [[-3.2867    ]],
#
#        [[-3.209625  ]],
#
#        [[-3.209625  ]],
#
#        [[-3.20648896]],
#
#        [[-3.13      ]],
#
#        [[-3.13      ]],
#
#        [[-3.047825  ]],
#
#        [[-3.047825  ]],
#
#        [[-2.997296  ]],
#
#        [[-2.9631    ]],
#
#        [[-2.875825  ]],
#
#        [[-2.875825  ]],
#
#        [[-2.786     ]]])

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال دوم:‌
#         </font>
# در این تمرین قصد داریم به تحلیل داده های فیلم های برتر سینمای جهان به معیار imdb بپردازیم. ابتدا دادههای مربوط به فیلم را از فایل csv فراخوانی میکنیم
#         <br/>
#     </font>
# </div>

# %%
movies = pd.read_csv("imdb_movie_rank.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         در این دیتاست اگر داده ای وجود دارد که مقدار nullدارد سطرش را حذف کنید.
#         <br/>
#     </font>
# </div>

# %%
movies.dropna()
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         فیلم ها را براساس مدت زمان فیلم به صورت نزولی مرتب کنید و پنجاه تای اول را در فایل csv با نام long_time ذخیره کنید
#         <br/>
#     </font>
# </div>

# %%
duration_sort = movies.sort_values(by = 'duration', ascending = False).head(50)
duration_sort.to_csv('long_time.csv')

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#          تابعی بنویسید که نام بازیگر را به عنوان آرگومان بگیرد و تعداد فیلم های برتر از این لیست را که بازی کرده محاسبه کند.
#         <br/>
#     </font>
# </div>

# %%
def RatedMovie(name):
    count = 0
    for i in range(len(movies['actors_list'])):
        if name in movies['actors_list'][i]:
            count+=1
    return count

RatedMovie('Christian Bale')
# Out:
# 11

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#          میانگین امتیاز فیلم ها را براساس ژانر نمایش به دست آورید.
#         <br/>
#     </font>
# </div>

# %%
movies[['genre','star_rating']].groupby(['genre']).mean()
# Out:
#            star_rating
# genre
# Action        7.884559
# Adventure     7.933333
# Animation     7.914516
# Biography     7.862338
# Comedy        7.822436
# Crime         7.916935
# Drama         7.902518
# Family        7.850000
# Fantasy       7.700000
# Film-Noir     8.033333
# History       8.000000
# Horror        7.806897
# Mystery       7.975000
# Sci-Fi        7.920000
# Thriller      7.680000
# Western       8.255556

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#        ستونی به این داده ها اضافه کنید که در صورت اینکه یک فیلم مدت نمایش آن 150 دقیقه و یا بیشتر بود مقدار صفر و در غیر اینصورت 1 در هر سطر این ستون قرار گیرد. دیتافریم حاصل را در یک فایل csv ذخیره کنید.
#         <br/>
#     </font>
# </div>

# %%
movies.loc[movies['duration'] >= 150, 'greaterthan'] = 0
movies.loc[movies['duration'] < 150, 'lessthan'] = 1
duration_sort.to_csv('greater_than_150.csv')

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         عنوان ستونها را به نحوی تغییر دهید که در ستون های دارای _(آندرلاین) فاصله قرار گیرد. به عنوان مثال star_rating به star rating تبدیل می شود.
#         <br/>
#     </font>
# </div>

# %%
movies.columns.str.replace('_', ' ')
# Out:
# Index(['star rating', 'title', 'content rating', 'genre', 'duration',
#        'actors list', 'greaterthan', 'lessthan'],
#       dtype='object')

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         داده ها را براساس ژانر گروه بندی و مرتب کنید و از هر ژانر صرفا سه تای برتر را نمایش دهید
#         <br/>
#     </font>
# </div>

# %%
movies.sort_values(by = 'genre', ascending = False).groupby(['genre']).head(3)
# Out:
#      star_rating                                      title content_rating  \
# 107          8.3                     For a Few Dollars More       APPROVED
# 421          7.9                     The Outlaw Josey Wales             PG
# 704          7.6                        High Plains Drifter              R
# 848          7.5                  The Man Who Knew Too Much             PG
# 350          8.0                          Shadow of a Doubt       APPROVED
# 728          7.6                         La piel que habito              R
# 637          7.7                       The Butterfly Effect              R
# 321          8.0                                     Brazil              R
# 145          8.2                               Blade Runner              R
# 46           8.5                                    Memento              R
# 110          8.3                      2001: A Space Odyssey              G
# ...

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال سوم:‌
#         </font>
#         تفاوت بین متد read_table و read_csv در ماژول pandas چیست؟
#         <br/>
#     </font>
# </div>

# %% [raw]
# You can get either to work for general delimited files, the difference are the default params,
# for instance sep is '\t' (tab) for read_table but ',' for read_csv.
# Theyre both implemented the same underneath
#
# read_csv = _make_parser_function('read_csv', sep=',')
# read_csv = Appender(_read_csv_doc)(read_csv)
#
# read_table = _make_parser_function('read_table', sep='\t')
# read_table = Appender(_read_table_doc)(read_table)
#
# and _make_parser_function:
# def _make_parser_function(name, sep=','):

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال چهارم:‌
#         </font>
#        توضیح دهید crosstab در پانداس چه میکند و عملکرد آنرا بر روی کد زیر توضیح دهید؟
#         <br/>
#     </font>
# </div>

# %%
pd.crosstab(movies.genre, movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %% [raw]
# This method is used to compute a simple cross-tabulation of two (or more) factors. By default, computes a frequency table of the factors unless an array of values and an aggregation function are passed.
#
# Syntax: pandas.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name=’All’, dropna=True, normalize=False)
#
# Arguments :
#
# index : array-like, Series, or list of arrays/Series, Values to group by in the rows.
# columns : array-like, Series, or list of arrays/Series, Values to group by in the columns.
# values : array-like, optional, array of values to aggregate according to the factors. Requires `aggfunc` be specified.
# rownames : sequence, default None, If passed, must match number of row arrays passed.
# colnames : sequence, default None, If passed, must match number of column arrays passed.
# aggfunc : function, optional, If specified, requires `values` be specified as well.
# margins : bool, default False, Add row/column margins (subtotals).
# margins_name : str, default ‘All’, Name of the row/column that will contain the totals when margins is True.
# dropna : bool, default True, Do not include columns whose entries are all NaN.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال پنچم:‌
#         </font>
#          توضیح دهید متد corr در پانداس چه میکند و عملکرد آنرا بر روی کد زیر توضیح دهید؟
#         <br/>
#     </font>
# </div>

# %%
movies.corr()
# Out:
#              star_rating  duration
# star_rating     1.000000  0.227149
# duration        0.227149  1.000000

# %% [raw]
# Pandas dataframe.corr() is used to find the pairwise correlation of all columns in the dataframe. Any na values are automatically excluded. For any non-numeric data type columns in the dataframe it is ignored.
#
# Syntax: DataFrame.corr(self, method=’pearson’, min_periods=1)
#
# Parameters:
# method :
# pearson : standard correlation coefficient
# kendall : Kendall Tau correlation coefficient
# spearman : Spearman rank correlation
# min_periods : Minimum number of observations required per pair of columns to have a valid result. Currently only available for pearson and spearman correlation
#
# Returns: count :y : DataFrame

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال سوم:‌
#         </font>
#         با استفاده از متد value_counts تعداد فیلمها در هر ریت محتوا را به دست آورید.
#         <br/>
#     </font>
# </div>

# %%
label = movies["star_rating"]
label.value_counts()
# Out:
# 7.6    124
# 7.8    116
# 7.7    113
# 7.5    108
# 8.1    103
# 8.0     97
# 7.9     75
# 8.2     51
# 7.4     49
# 8.3     43
# 8.4     37
# 8.5     23
# 8.6     15
# 8.7     10
# 8.9      6
# 8.8      5
# 9.2      1
# 9.0      1
# 9.1      1
# 9.3      1
# Name: star_rating, dtype: int64

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال ششم:‌
#         </font>
#         با استفاده از متد sample هفتاد و پنج درصد سطرها را در یک متغیر به نام sample_1 بریزید. درنهایت با استفاده از متد drop از دیتافریم اصلی این سطرها را حذف و دیتافریم جدید را در sample_2 بریزید
#         <br/>
#     </font>
# </div>

# %%
sample1 = movies.sample(frac =.75)
sample2=movies.drop(sample1.index)
sample2
# Out:
#      star_rating                                              title  \
# 6            8.9                     The Good, the Bad and the Ugly
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 17           8.7                                      Seven Samurai
# 20           8.7                                         The Matrix
# ..           ...                                                ...
# 958          7.4                                 My Sister's Keeper
# 961          7.4                                             Capote
# 973          7.4                              The Cider House Rules
# 977          7.4                                        Poltergeist
# 978          7.4                                        Wall Street
#
#     content_rating      genre  duration  \
# 6        NOT RATED    Western       161
# 10           PG-13  Adventure       178
# ...

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال هفتم:‌
#         </font>
#          متد pivot_table چه عملکردی دارد؟
#         <br/>
#     </font>
# </div>

# %% [raw]
# pandas.pivot_table
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True)[source]
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# dataDataFrame
# valuescolumn to aggregate, optional
# indexcolumn, Grouper, array, or list of the previous
# If an array is passed, it must be the same length as the data. The list can contain any of the other types (except list). Keys to group by on the pivot table index. If an array is passed, it is being used as the same manner as column values.
#
# columnscolumn, Grouper, array, or list of the previous
# If an array is passed, it must be the same length as the data. The list can contain any of the other types (except list). Keys to group by on the pivot table column. If an array is passed, it is being used as the same manner as column values.
#
# aggfuncfunction, list of functions, dict, default numpy.mean
# If list of functions passed, the resulting pivot table will have hierarchical columns whose top level are the function names (inferred from the function objects themselves) If dict is passed, the key is column to aggregate and value is function or list of functions.
#
# fill_valuescalar, default None
# Value to replace missing values with (in the resulting pivot table, after aggregation).
#
# marginsbool, default False
# Add all row / columns (e.g. for subtotal / grand totals).
#
# dropnabool, default True
# Do not include columns whose entries are all NaN.
#
# margins_namestr, default ‘All’
# Name of the row / column that will contain the totals when margins is True.
#
# observedbool, default False
