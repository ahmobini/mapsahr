# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mobile_usage_history.csv')

# %%
df
# Out:
#           day subscriber_ecid  subscriber_gender  subscriber_age  \
# 0       (n)01   -06FoayTOXJ8-                  1            36.0
# 1       (n)02   -06FoayTOXJ8-                  1            36.0
# 2       (n)03   -06FoayTOXJ8-                  1            36.0
# 3       (n)04   -06FoayTOXJ8-                  1            36.0
# 4       (n)05   -06FoayTOXJ8-                  1            36.0
# ...       ...             ...                ...             ...
# 6558  (n+2)03   4VP-NCllX2jqU                  1            55.0
# 6559  (n+2)04   4VP-NCllX2jqU                  1            55.0
# 6560  (n+2)05   4VP-NCllX2jqU                  1            55.0
# 6561  (n+2)06   4VP-NCllX2jqU                  1            55.0
# 6562  (n+2)07   4VP-NCllX2jqU                  1            55.0
#
#       registration_province  months_of_subscription  most_used_province  \
# 0                         8                     188                   8
# ...

# %%
df.day.unique().shape #number of days in the dataset
# Out:
# (69,)

# %%
df.subscriber_ecid.unique().shape
# Out:
# (100,)

# %%
data_usage_df = df['day subscriber_ecid data_usage_volume'.split()]

# %%
data_usage_df[data_usage_df.subscriber_ecid == '-06FoayTOXJ8-']
# Out:
#         day subscriber_ecid  data_usage_volume
# 0     (n)01   -06FoayTOXJ8-           0.072258
# 1     (n)02   -06FoayTOXJ8-           0.049563
# 2     (n)03   -06FoayTOXJ8-          -0.013977
# 3     (n)04   -06FoayTOXJ8-           0.000403
# 4     (n)05   -06FoayTOXJ8-           0.016209
# ..      ...             ...                ...
# 64  (n+2)03   -06FoayTOXJ8-          -0.013948
# 65  (n+2)04   -06FoayTOXJ8-          -0.013977
# 66  (n+2)05   -06FoayTOXJ8-          -0.013977
# 67  (n+2)06   -06FoayTOXJ8-          -0.013977
# 68  (n+2)07   -06FoayTOXJ8-          -0.013977
#
# [69 rows x 3 columns]

# %%
data_usage_df.pivot(index='subscriber_ecid', columns='day', values='data_usage_volume')
# Out:
# day                  (n)01      (n)02     (n)03     (n)04     (n)05     (n)06  \
# subscriber_ecid
# -06FoayTOXJ8-     0.072258   0.049563 -0.013977  0.000403  0.016209  0.022840
# -A-7LJ6WUTKfm     4.307190   4.441118  5.134305  6.986763  5.625852  8.029044
# -Ajqu-Pi5VJde     0.022914  -0.010756  0.013161 -0.012447 -0.013470 -0.011269
# -DgEYYT0gqMqr    -0.013977  -0.013977 -0.013977 -0.013977 -0.013977 -0.013977
# -Ej3Gtwwcsf46    -0.013977  -0.013977  0.061952 -0.013977  0.023044 -0.013977
# ...                    ...        ...       ...       ...       ...       ...
# 4FZppZ0yFa5OG    -0.013977  -0.013977  0.121827  0.039258  0.127953  0.063090
# 4Gr5JueCKLbR0     2.302267   3.821248  4.449315  2.757663  0.321596  1.667758
# 4JYt7OYE9n7m6    -0.013977  -0.013977 -0.013501 -0.013977 -0.013977 -0.013977
# 4TVsEbq2uvIRR    31.687991  10.042914  6.718659  8.700161  3.177159  5.390012
# 4VP-NCllX2jqU    -0.013977  -0.013977 -0.013977 -0.013977 -0.013977 -0.013977
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6563 entries, 0 to 6562
# Data columns (total 34 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   day                                   6563 non-null   object
#  1   subscriber_ecid                       6563 non-null   object
#  2   subscriber_gender                     6563 non-null   int64
#  3   subscriber_age                        6563 non-null   float64
#  4   registration_province                 6563 non-null   int64
#  5   months_of_subscription                6563 non-null   int64
#  6   most_used_province                    6563 non-null   int64
#  7   is_usage_nonzero                      6563 non-null   int64
#  8   subscriber_total_expenses             6563 non-null   float64
#  9   nonpackage_voice_expenses             6563 non-null   float64
#  10  package_voice_noncash_expenses        6563 non-null   float64
# ...

# %%
df.package_voice_noncash_expenses.unique()
# Out:
# array([     0., 325910., 162410., 434910., 545000.,  10900.])

# %%
grouped = df.groupby("subscriber_ecid").nunique()

# %%
g = grouped.nunique()
g[g==1]
# Out:
# subscriber_gender         1
# subscriber_age            1
# registration_province     1
# months_of_subscription    1
# dtype: int64

# %%
grouped.apply(np.unique)
# Out:
# day                                                [1, 2, 18, 22, 53, 60, 61, 67, 68, 69]
# subscriber_gender                                                                     [1]
# subscriber_age                                                                        [1]
# registration_province                                                                 [1]
# months_of_subscription                                                                [1]
# most_used_province                                           [1, 2, 3, 4, 5, 7, 8, 9, 11]
# is_usage_nonzero                                                                   [1, 2]
# subscriber_total_expenses               [1, 2, 3, 6, 7, 9, 10, 11, 18, 19, 23, 27, 29,...
# nonpackage_voice_expenses               [1, 2, 3, 4, 6, 8, 12, 17, 18, 19, 21, 22, 27,...
# package_voice_noncash_expenses                                                  [1, 2, 3]
# ...

# %%
grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, -06FoayTOXJ8- to 4VP-NCllX2jqU
# Data columns (total 33 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   day                                   100 non-null    int64
#  1   subscriber_gender                     100 non-null    int64
#  2   subscriber_age                        100 non-null    int64
#  3   registration_province                 100 non-null    int64
#  4   months_of_subscription                100 non-null    int64
#  5   most_used_province                    100 non-null    int64
#  6   is_usage_nonzero                      100 non-null    int64
#  7   subscriber_total_expenses             100 non-null    int64
#  8   nonpackage_voice_expenses             100 non-null    int64
#  9   package_voice_noncash_expenses        100 non-null    int64
#  10  is_voice_expenses_nonzero             100 non-null    int64
# ...
