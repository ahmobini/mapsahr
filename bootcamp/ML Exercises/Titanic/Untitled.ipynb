# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic_df = sns.load_dataset('titanic')

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic_df.hist(figsize = (20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'pclass'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sibsp'}>],
#        [<AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>]], dtype=object)

# %%
titanic_df.boxplot(figsize =(10,10))
# Out:
# <AxesSubplot:>

# %%
titanic_df.boxplot(by = ['survived'], column = ['age'], figsize = (10,10))
titanic_df.boxplot(by = ['survived'], column = ['alone'], figsize = (10,5))
titanic_df.boxplot(by = ['sex'], column=['age'], figsize = (10,10))
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='[sex]'>

# %%
titanic_df.plot.scatter('survived','sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='sex'>

# %%
pd.plotting.scatter_matrix(titanic_df[['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare']], figsize=(20,15))
# Out:
# array([[<AxesSubplot:xlabel='survived', ylabel='survived'>,
#         <AxesSubplot:xlabel='pclass', ylabel='survived'>,
#         <AxesSubplot:xlabel='age', ylabel='survived'>,
#         <AxesSubplot:xlabel='sibsp', ylabel='survived'>,
#         <AxesSubplot:xlabel='parch', ylabel='survived'>,
#         <AxesSubplot:xlabel='fare', ylabel='survived'>],
#        [<AxesSubplot:xlabel='survived', ylabel='pclass'>,
#         <AxesSubplot:xlabel='pclass', ylabel='pclass'>,
#         <AxesSubplot:xlabel='age', ylabel='pclass'>,
#         <AxesSubplot:xlabel='sibsp', ylabel='pclass'>,
#         <AxesSubplot:xlabel='parch', ylabel='pclass'>,
#         <AxesSubplot:xlabel='fare', ylabel='pclass'>],
#        [<AxesSubplot:xlabel='survived', ylabel='age'>,
#         <AxesSubplot:xlabel='pclass', ylabel='age'>,
#         <AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='sibsp', ylabel='age'>,
#         <AxesSubplot:xlabel='parch', ylabel='age'>,
# ...
